# %%
import pandas as pd
import numpy as np
import os
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/sbox/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /home/sbox/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
folder = 'aclImdb'
labels = {'pos': 1, 'neg': 0}

df = pd.DataFrame()

for f in ('test', 'train'):
    for l in ('pos', 'neg'):
        path = os.path.join(folder, f, l)
        for file in os.listdir (path) :
            with open(os.path.join(path, file),'r', encoding='utf-8') as infile:
                txt = infile.read()
            df = df.append([[txt, labels[l]]],ignore_index=True)
df.columns = ['review', 'sentiment']

# %%
df.to_csv('movie_review.csv',encoding='utf-8',index= False)
df.head()
# Out:
#                                               review  sentiment
# 0  I don't have a really solid thesis here, so I'...          1
# 1  Topless touch football!! A wet t-shirt contest...          1
# 2  Although this film changes reality to make it ...          1
# 3  I must admit, I liked this movie, and didnt fi...          1
# 4  I was recommended this film as one of the best...          1

# %%
reviews = df.review.str.cat(sep=' ')

# %%
tokens = word_tokenize(reviews)

# %%
vocabulary = set(tokens)

# %%
frequency_dist = nltk.FreqDist(tokens)

# %%
print(len(vocabulary))
# Out:
# 198763

# %%
sorted(frequency_dist,key=frequency_dist.__getitem__, reverse=True)[0:50]
# Out:
# ['the',
#  ',',
#  '.',
#  'a',
#  'and',
#  'of',
#  'to',
#  'is',
#  '/',
#  '>',
#  '<',
#  'br',
#  'in',
#  'I',
#  'it',
#  'that',
#  "'s",
#  'this',
#  'was',
#  'The',
#  'as',
#  'with',
#  'movie',
#  'for',
#  'film',
#  ')',
#  '(',
#  'but',
#  "''",
#  "n't",
#  '``',
#  'on',
#  'you',
#  'are',
#  'not',
#  'have',
#  'his',
#  'be',
#  '!',
#  'he',
#  'one',
#  'at',
#  'by',
#  'an',
#  'all',
#  'who',
#  'they',
#  'from',
#  'like',
#  'It']

# %%
stop_words = set(stopwords.words('english'))
tokens = [w for w in tokens if not w in stop_words]

# %%
wordcloud =WordCloud().generate_from_frequencies(frequency_dist)

# %%
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
frequenxy_dist1 = nltk.FreqDist(tokens)

# %%
sorted(frequenxy_dist1,key=frequency_dist.__getitem__, reverse=True)[0:50]
# Out:
# [',',
#  '.',
#  '/',
#  '>',
#  '<',
#  'br',
#  'I',
#  "'s",
#  'The',
#  'movie',
#  'film',
#  ')',
#  '(',
#  "''",
#  "n't",
#  '``',
#  '!',
#  'one',
#  'like',
#  'It',
#  '?',
#  'This',
#  'good',
#  'would',
#  '...',
#  'time',
#  'really',
#  'see',
#  'even',
#  'story',
#  "'",
#  ':',
#  '-',
#  'much',
#  'could',
#  'get',
#  'people',
#  'bad',
#  'great',
#  'well',
#  'first',
#  'made',
#  'also',
#  'make',
#  'way',
#  'movies',
#  'But',
#  'think',
#  'characters',
#  'character']

# %%
wordcloud1 =WordCloud().generate_from_frequencies(frequenxy_dist1)

# %%
plt.imshow(wordcloud1)
plt.axis("off")
plt.show()

# %%
X_train = df.loc[:24999, 'review'].values
Y_train = df.loc[:24999,'sentiment'].values

# %%
X_test = df.loc[25000:,'review'].values
Y_test = df.loc[25000:,'sentiment'].values

# %%
vectorizer = TfidfVectorizer()

# %%
train_vectors = vectorizer.fit_transform(X_train)
test_vectors = vectorizer.transform(X_test)
print(train_vectors.shape, test_vectors.shape)
# Out:
# (25000, 73822) (25000, 73822)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
clf = MultinomialNB().fit(train_vectors, Y_train)

# %%
from  sklearn.metrics  import accuracy_score
predicted = clf.predict(test_vectors)
print(accuracy_score(Y_test,predicted))
# Out:
# 0.83664
